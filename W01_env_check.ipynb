# %%
import sys

print("Python executable:", sys.executable)
print("Python version:", sys.version)
# Out:
# Python executable: /Users/burneyx1a/Desktop/College Stuff/InGen_Internship/.venv/bin/python
# Python version: 3.11.9 (v3.11.9:de54cf5be3, Apr  2 2024, 07:12:50) [Clang 13.0.0 (clang-1300.0.29.30)]

# %%
import pandas as pd
import numpy as np
import scipy
import sklearn
import torch
import pyod
import statsmodels.api as sm
import plotly.express as px
import streamlit as st

print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("scipy:", scipy.__version__)
print("sklearn:", sklearn.__version__)
print("torch:", torch.__version__)
print("pyod:", pyod.__version__)
print("statsmodels:", sm.__version__)
print("streamlit:", st.__version__)
print("Environment check passed.")
# Out:
# pandas: 3.0.3
# numpy: 2.4.6
# scipy: 1.17.1
# sklearn: 1.9.0
# torch: 2.12.1
# pyod: 3.6.1
# statsmodels: 0.14.6
# streamlit: 1.58.0
# Environment check passed.

# %%
from sklearn.ensemble import IsolationForest
data = pd.DataFrame({
    "robot_sensor_1": np.random.normal(0, 1, 100),
    "robot_sensor_2": np.random.normal(5, 2, 100)
})

model = IsolationForest(random_state=42)
data["anomaly_score"] = model.fit_predict(data)

data.head()
# Out:
#    robot_sensor_1  robot_sensor_2  anomaly_score
# 0       -0.855808        6.628595              1
# 1        0.087454        7.013568              1
# 2        1.567891        4.881046             -1
# 3        0.264784        3.399348              1
# 4       -0.392601        5.595373              1
